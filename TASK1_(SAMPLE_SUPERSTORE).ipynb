# %%
#NAME: ANURADHA JAISWAL

# %%
#IMPORT important libraries
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
super_store=pd.read_csv("/content/SampleSuperstore.csv")
super_store.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
super_store.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
super_store.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
super_store.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
super_store.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
super_store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
super_store.shape
# Out:
# (9994, 13)

# %%
super_store.duplicated().sum()
# Out:
# 17

# %%
super_store.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
super_store.Country.value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
super_store.City.value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
super_store.Sales.value_counts()
# Out:
# 12.960     56
# 19.440     39
# 15.552     39
# 25.920     36
# 10.368     36
#            ..
# 4.240       1
# 319.960     1
# 646.740     1
# 81.940      1
# 243.160     1
# Name: Sales, Length: 5825, dtype: int64

# %%
super_store.Profit.value_counts()
# Out:
# 0.0000     65
# 6.2208     43
# 9.3312     38
# 5.4432     32
# 3.6288     32
#            ..
# 83.2508     1
# 16.1096     1
# 7.1988      1
# 1.6510      1
# 72.9480     1
# Name: Profit, Length: 7287, dtype: int64

# %%
super_store.Discount.value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
super_store.info
# Out:
# <bound method DataFrame.info of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#HEAT MAP
corr=super_store.corr()
sns.heatmap(corr,annot=True)
# Out:
# <ipython-input-34-ad632b91936e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=super_store.corr()
# <Axes: >

# %%
#BOXPLOT
plt.figure(figsize=(55,8))
sns.boxplot(x='State',y='Sales',data=super_store)
# Out:
# <Axes: xlabel='State', ylabel='Sales'>

# %%
#BOXPLOT
plt.figure(figsize=(55,9))
sns.boxplot(x='State',y='Profit',data=super_store)
# Out:
# <Axes: xlabel='State', ylabel='Profit'>

# %%
#BOXPLOT
#plt.figure(figsize=(15,5))
sns.lineplot(x='Category',y='Sales',data=super_store)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
#BOXPLOT
plt.figure(figsize=(15,5))
sns.lineplot(x='Sub-Category',y='Sales',data=super_store)
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Sales'>

# %%
sns.countplot(x='Discount',data=super_store)
# Out:
# <Axes: xlabel='Discount', ylabel='count'>

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x='Sub-Category',y='Profit',data=super_store)
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Profit'>

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x='Sub-Category',y='Discount',data=super_store)
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Discount'>

# %%
sns.pairplot(super_store,hue='Ship Mode')

# %%
sns.pairplot(super_store,hue='Segment')
